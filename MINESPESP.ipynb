# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

if server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
if server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

if server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version



jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]


if colabconfig["server_version"] < "1.17":
    #en la segunda linea de este if puedes cambiar la version de java que quieres instalar, (openjdk-𝟠-jre- (En el 8 puedes cambiarlo si lo necesitas dependiendo del error que te salga))
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-8-jre-headless &>/dev/null') and print("OpenJDK 8 installed") or print("Failed to install OpenJDK 8.")
# Instalar OpenJDK 17 si la version de Minecraft es 1.17 o superior
else:
    os.system('sudo apt-get purge openjdk* > /dev/null 2>&1')
    os.system('sudo apt-get install openjdk-17-jre-headless &>/dev/null') and print("OpenJDK 17 installed") or print("Failed to install OpenJDK 17.")

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))

elif tunnel_service == "playit":

    ! curl -SsL https://playit-cloud.github.io/ppa/key.gpg | sudo apt-key add -
    ! sudo curl -SsL -o /etc/apt/sources.list.d/playit-cloud.list https://playit-cloud.github.io/ppa/playit-cloud.list
    ! sudo apt update &>/dev/null && sudo apt install playit &>/dev/null && echo "Playit.gg installed" || echo "Failed to install playit"
    print('Starting server...')
    ! playit & java $memory_allocation $server_flags -jar $jar_name nogui
    
    
elif tunnel_service == "zerotier":
    # Instalar ZeroTier
    # !curl -s https://install.zerotier.com | sudo bash

    # Ingresar a tu red de ZeroTier
    zerotier_network_id = "YOUR_NETWORK_ID"  # Remplaza con tu id de red de ZeroTier
    # !sudo zerotier-cli join $zerotier_network_id

    # Esperar a que ZeroTier se una a la red
    import time
    time.sleep(120)  # Aumentalo si es neceasrio

    #Chequea el estado de ZeroTier
    # !sudo zerotier-cli status


print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      delete	    mohist-config    server.properties
# banned-players.json  eula.txt	    mohist.jar	     spigot.yml
# bukkit.yml	     forge.jar	    ops.json	     user_jvm_args.txt
# colabconfig.json     forge.jar.log  patchouli_books  usercache.json
# commands.yml	     help.yml	    permissions.yml  usernamecache.json
# config		     libraries	    plugins	     whitelist.json
# crash-reports	     logs	    run.bat	     world
# defaultconfigs	     mods	    run.sh
# Failed to install OpenJDK 17.
# Reading package lists...Usando ngrok
#
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   ca-certificates-java java-common libpcsclite1
# Suggested packages:
#   default-jre pcscd libnss-mdns fonts-dejavu-extra fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   ca-certificates-java java-common libpcsclite1 openjdk-17-jre-headless
# 0 upgraded, 4 newly installed, 0 to remove and 29 not upgraded.
# Need to get 43.7 MB of archives.
# After this operation, 193 MB of additional disk space will be used.
# Do you want to continue? [Y/n] Abort.
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# authtoken -
#
# USAGE:
#   ngrok authtoken TOKEN [flags]
#
# AUTHOR:
#   ngrok - <support@ngrok.com>
#
# COMMANDS:
#   config          update or migrate ngrok's configuration file
#   http            start an HTTP tunnel
#   tcp             start a TCP tunnel
#   tunnel          start a tunnel for use with a tunnel-group backen
#
# EXAMPLES:
#   ngrok http 80                                                 # secure public URL for port 80 web server
#   ngrok http --domain baz.ngrok.dev 8080                        # port 8080 available at baz.ngrok.dev
#   ngrok tcp 22                                                  # tunnel arbitrary TCP traffic to port 22
#   ngrok http 80 --oauth=google --oauth-allow-email=foo@foo.com  # secure your app with oauth
#
# Paid Features:
#   ngrok http 80 --domain mydomain.com                           # run ngrok with your own custom domain
#   ngrok http 80 --allow-cidr 2600:8c00::a03c:91ee:fe69:9695/32  # run ngrok with IP policy restrictions
#   Upgrade your account at https://dashboard.ngrok.com/billing/subscription to access paid features
#
# Upgrade your account at https://dashboard.ngrok.com/billing/subscription to access paid features
#
# Flags:
#   -h, --help      help for ngrok
#
# Use "ngrok [command] --help" for more information about a command.
#
# ERROR:  accepts 1 arg(s), received 0
# La IP de tu servidor es 0.tcp.ngrok.io:13253
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 44290
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-593 but you have 1.20.1-580. The latest version has been built on 2024-03-04 06:38:48. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [04:46:43 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [04:46:43 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [04:46:44 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [04:46:44 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [04:46:44 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [04:46:44 INFO]: Found 14 dependencies adding them to mods collection
# [04:46:47 INFO]: Compatibility level set to JAVA_17
# [04:46:47 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [04:46:47 WARN]: Reference map 'untamedwilds.refmap.json' for mixins.untamedwilds.json could not be read. If this is a development environment you can ignore this message
# [04:46:47 WARN]: Reference map 'simplyswords-forge-refmap.json' for simplyswords.mixins.json could not be read. If this is a development environment you can ignore this message
# [04:46:47 WARN]: Reference map 'justhammers-common-refmap.json' for justhammers-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [04:46:47 INFO]: Loaded configuration file for Canary: 116 options available, 0 override(s) found
# [04:46:47 INFO]: Loading 85 mods:
# 	- alexscaves 1.1.2
# 	- alexsmobs 1.22.7
# 	- apotheosis 7.3.0
# 	- apothiccurios 1.0.3b
# 	- aquacombat 1.2
# 	- aquamirae 6.API15
# 	- architectury 9.2.14
# 	- athena 3.1.1
# 	- attributefix 21.0.4
# 	- attributeslib 1.2.1
# 	- balm 7.2.2
# 	- bettercombat 1.8.4+1.20.1
# 	- betterdeserttemples 1.20-Forge-3.0.3
# 	- betterdungeons 1.20-Forge-4.0.3
# 	- betterendisland 1.20-Forge-2.0.5
# 	- betterfortresses 1.20-Forge-2.0.5
# 	- betterjungletemples 1.20-Forge-2.0.4
# 	- bettermineshafts 1.20-Forge-4.0.4
# 	- betteroceanmonuments 1.20-Forge-3.0.4
# 	- betterthirdperson 1.9.0
# 	- betterwitchhuts 1.20-Forge-3.0.3
# 	- biome_beans 1.0.2
# 	- bookshelf 20.1.9
# 	- caelus 3.1.0+1.20
# 	- canary 0.3.3
# 	- cataclysm 1.0
# 	- chipped 3.0.4
# 	- chiselsandbits 1.4.147
# 	- citadel 2.5.3
# 	- cloth_config 11.1.118
# 	- colorfulhearts 4.0.4
# 	- comforts 6.3.5+1.20.1
# 	- cosmeticarmorreworked 1.20.1-v1a
# 	- create 0.5.1.f
# 	- creativecore 2.11.24
# 	- curios 5.7.0+1.20.1
# 	- domesticationinnovation 1.7.1
# 	- dynamiclights 1.20.1.2
# 	- effortlessbuilding 3.7
# 	- enchantsmith 1.0.3-1.20
# 	- endrem 5.2.3-R-1.20.1
# 	- flywheel 0.6.10-7
# 	- forge 47.2.20
# 	- geckolib 4.4.2
# 	- guardvillagers 1.20.1-1.6.4
# 	- iceandfire 2.1.13-1.20.1-beta-4
# 	- idas 1.8.5+1.20.1
# 	- insanelib 1.12.1
# 	- integrated_api 1.4.0+1.20.1-forge
# 	- irons_spellbooks 1.20.1-3.0.0
# 	- itemproductionlib 1.0.2a
# 	- jei 15.3.0.4
# 	- justhammers 2.0.3+mc1.20.1
# 	- leavesbegone 8.0.0
# 	- maxhealthfix 12.0.2
# 	- minecraft 1.20.1
# 	- mixinextras 0.3.2
# 	- mixinsquared 0.1.1
# 	- mohist 1.20.1
# 	- moonlight 1.20-2.10.9
# 	- obscure_api 15
# 	- obscure_tooltips 2.2
# 	- parcool 1.20.1-3.1.0.6-R
# 	- patchouli 1.20.1-84-FORGE
# 	- placebo 8.6.1
# 	- playeranimator 1.0.2-rc1+1.20
# 	- playerrevive 2.0.24
# 	- progressivebosses 3.9.5-mc1.20.1
# 	- puzzlesaccessapi 8.0.7
# 	- puzzleslib 8.1.17
# 	- quark 4.0-436
# 	- resourcefullib 2.1.23
# 	- scena 1.0.103
# 	- simplyswords 1.54.0-1.20.1
# 	- skilltree 0.6.10a
# 	- sophisticatedbackpacks 3.20.1.1012
# 	- sophisticatedcore 0.6.3.553
# 	- spectrelib 0.13.15+1.20.1
# 	- supplementaries 1.20-2.8.1
# 	- tombstone 8.6.3
# 	- untamedwilds 4.0.4
# 	- w2pets 1.0
# 	- waystones 14.1.3
# 	- yungsapi 1.20-Forge-4.0.3
# 	- zeta 1.0-13
# [04:46:47 WARN]: Reference map 'chiselsandbits.refmap.json' for chisels-and-bits.mixins.json could not be read. If this is a development environment you can ignore this message
# [04:46:47 WARN]: Reference map 'Aquamirae.refmap.json' for aquamirae.mixins.json could not be read. If this is a development environment you can ignore this message
# [04:46:48 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [04:46:48 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [04:46:48 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [04:46:48 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [04:46:48 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [04:46:49 WARN]: Error loading class: com/hollingsworth/arsnouveau/common/items/SpellCrossbow (java.lang.ClassNotFoundException: com.hollingsworth.arsnouveau.common.items.SpellCrossbow)
# [04:46:49 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [04:46:49 INFO]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [04:46:49 WARN]: Error loading class: tfar/davespotioneering/blockentity/AdvancedBrewingStandBlockEntity (java.lang.ClassNotFoundException: tfar.davespotioneering.blockentity.AdvancedBrewingStandBlockEntity)
# [04:46:49 WARN]: @Mixin target tfar.davespotioneering.blockentity.AdvancedBrewingStandBlockEntity was not found itemproductionlib.mixins.json:davespotioneering/AdvancedBrewingStandBlockEntityMixin
# [04:46:49 WARN]: Error loading class: vectorwing/farmersdelight/common/block/entity/CookingPotBlockEntity (java.lang.ClassNotFoundException: vectorwing.farmersdelight.common.block.entity.CookingPotBlockEntity)
# [04:46:49 WARN]: @Mixin target vectorwing.farmersdelight.common.block.entity.CookingPotBlockEntity was not found itemproductionlib.mixins.json:farmersdelight/CookingPotBlockEntityMixin
# [04:46:49 WARN]: Error loading class: vectorwing/farmersdelight/common/block/entity/StoveBlockEntity (java.lang.ClassNotFoundException: vectorwing.farmersdelight.common.block.entity.StoveBlockEntity)
# [04:46:49 WARN]: @Mixin target vectorwing.farmersdelight.common.block.entity.StoveBlockEntity was not found itemproductionlib.mixins.json:farmersdelight/StoveBlockEntityMixin
# [04:46:49 WARN]: Error loading class: fuzs/visualworkbench/world/inventory/ModCraftingMenu (java.lang.ClassNotFoundException: fuzs.visualworkbench.world.inventory.ModCraftingMenu)
# [04:46:49 WARN]: @Mixin target fuzs.visualworkbench.world.inventory.ModCraftingMenu was not found itemproductionlib.mixins.json:visualworkbench/ModCraftingMenuMixin
# [04:46:49 INFO]: Patching FishingHook#catchingFish
# [04:46:49 WARN]: Error loading class: fuzs/easymagic/world/inventory/ModEnchantmentMenu (java.lang.ClassNotFoundException: fuzs.easymagic.world.inventory.ModEnchantmentMenu)
# [04:46:49 WARN]: @Mixin target fuzs.easymagic.world.inventory.ModEnchantmentMenu was not found skilltree.mixins.json:easymagic/ModEnchantmentMenuMixin
# [04:46:49 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/CreativeModeTabs
# [04:46:49 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [04:46:49 INFO]: Replaced 1 calls to Enchantment#isTreasureOnly() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [04:46:49 INFO]: Replaced 1 calls to Enchantment#isTradeable() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [04:46:49 WARN]: Error loading class: noobanidus/mods/lootr/config/ConfigManager (java.lang.ClassNotFoundException: noobanidus.mods.lootr.config.ConfigManager)
# [04:46:50 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [04:46:52 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/CreativeModeTabs
# [04:46:53 INFO]: Replaced 5 calls to Enchantment#getMaxLevel() in org/violetmoon/quark/content/tools/module/AncientTomesModule
# [04:46:53 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [04:46:53 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [04:46:54 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [04:46:56 WARN]: @Final field f_26027_:Lnet/minecraft/world/entity/ai/targeting/TargetingConditions; in guardvillagers.mixins.json:DefendVillageGoalGolemMixin should be final
# [04:46:56 INFO]: Patching FishingHook#catchingFish
# [04:46:57 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [04:46:57 INFO]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [04:46:58 INFO]: Initialized scena-forge
# [04:46:58 ERROR]: Could not find parent net/minecraft/client/renderer/entity/layers/RenderLayer for class com/obscuria/obscureapi/client/renderer/PatreonLayer in classloader cpw.mods.modlauncher.TransformingClassLoader@3e2d44f3 on thread Thread[#38,modloading-worker-0,5,main]
# [04:46:58 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.RenderLayer
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?]
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?]
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?]
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?]
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?]
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?]
# 	at com.obscuria.obscureapi.client.renderer.PatreonLayer$Mode.<clinit>(PatreonLayer.java:55) ~[obscure_api-15.jar%23314!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPIConfig$Client.<clinit>(ObscureAPIConfig.java:28) ~[obscure_api-15.jar%23314!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPIConfig.register(ObscureAPIConfig.java:46) ~[obscure_api-15.jar%23314!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPI.<init>(ObscureAPI.java:69) ~[obscure_api-15.jar%23314!/:com.obscuria]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23346!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23345!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# [04:46:58 ERROR]: Attempted to load class com/obscuria/obscureapi/client/renderer/PatreonLayer for invalid dist DEDICATED_SERVER
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.TagsFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.FixFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.AEC3DFeature
# [04:46:58 INFO]: Loaded maxhealthfix for Forge.
# [04:46:58 INFO]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [04:46:58 INFO]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [04:46:58 INFO]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [04:46:58 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [04:46:58 INFO]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [04:46:58 INFO]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [04:46:58 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.wither.feature.RewardFeature
# [04:46:58 INFO]: Loading compatibility module with Patchouli
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.wither.feature.ResistancesFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.wither.feature.MiscFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.wither.feature.MinionFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.wither.feature.HealthFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.wither.feature.DifficultyFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.wither.feature.AttackFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.elderguardian.feature.RewardFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.elderguardian.feature.ResistancesFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.elderguardian.feature.MinionFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.elderguardian.feature.HealthFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.elderguardian.feature.BaseFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.elderguardian.feature.AttackFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.dragon.feature.RewardFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.dragon.feature.ResistancesFeature
# [04:46:58 WARN]: @Final field f_31201_:Lorg/slf4j/Logger; in progressivebosses.mixins.json:DragonChargePlayerPhaseMixin should be final
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.dragon.feature.MinionFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.dragon.feature.LarvaFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.dragon.feature.HealthFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.dragon.feature.DifficultyFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.dragon.feature.CrystalFeature
# [04:46:58 INFO]: Found (COMMON) InsaneLib Feature class insane96mcp.progressivebosses.module.dragon.feature.AttackFeature
# [04:46:58 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [04:46:58 INFO]: MinecraftForge v47.2.20 Initialized
# [04:46:58 INFO]: NeoForge v47.2.20 Initialized
# [04:46:58 INFO]: Constructing common components for leavesbegone:main
# [04:46:58 INFO]: Mohist mod loading.....
# [04:46:58 INFO]: EventDispatcherRegistry initialized
# [04:47:00 INFO]: Replaced 5 calls to Enchantment#getMaxLevel() in org/violetmoon/quark/content/tools/module/AncientTomesModule
# [04:47:00 INFO]: Discovered 160 modules to load.
# [04:47:00 INFO]: Constructing module Abacus...
# [04:47:00 INFO]: Constructing module Adjustable Chat...
# [04:47:00 INFO]: Constructing module Ambient Discs...
# [04:47:00 INFO]: Constructing module Ancient Tomes...
# [04:47:00 INFO]: Replaced 3 calls to Enchantment#getMaxLevel() in org/violetmoon/quark/content/tools/item/AncientTomeItem
# [04:47:00 INFO]: Constructing module Ancient Wood...
# [04:47:00 INFO]: Constructing module Armed Armor Stands...
# [04:47:00 INFO]: Constructing module Auto Walk Keybind...
# [04:47:00 INFO]: Constructing module Automatic Recipe Unlock...
# [04:47:00 INFO]: Constructing module Automatic Tool Restock...
# [04:47:00 INFO]: Constructing module Azalea Wood...
# [04:47:00 INFO]: Constructing module Back Button Keybind...
# [04:47:00 INFO]: Constructing module Backpack...
# [04:47:00 INFO]: Constructing module Beacon Redirection...
# [04:47:00 INFO]: Constructing module Better Elytra Rocket...
# [04:47:00 INFO]: Constructing module Big Stone Clusters...
# [04:47:00 INFO]: Constructing module Blossom Trees...
# [04:47:00 INFO]: Constructing module Bottled Cloud...
# [04:47:00 INFO]: Constructing module Buckets Show Inhabitants...
# [04:47:00 INFO]: Constructing module Camera...
# [04:47:00 INFO]: Constructing module Campfires Boost Elytra...
# [04:47:00 INFO]: Constructing module Celebratory Lamps...
# [04:47:00 INFO]: Constructing module Chains Connect Blocks...
# [04:47:00 INFO]: Constructing module Chest Searching...
# [04:47:00 INFO]: Constructing module Chorus Vegetation...
# [04:47:00 INFO]: Constructing module Chute...
# [04:47:00 INFO]: Constructing module Climate Control Remover...
# [04:47:00 INFO]: Constructing module Color Runes...
# [04:47:00 INFO]: Constructing module Compasses Work Everywhere...
# [04:47:00 INFO]: Constructing module Compressed Blocks...
# [04:47:00 INFO]: Constructing module Coral On Cactus...
# [04:47:00 INFO]: Constructing module Corundum...
# [04:47:00 INFO]: Constructing module Crabs...
# [04:47:00 INFO]: Constructing module Crafter...
# [04:47:00 INFO]: Constructing module Crate...
# [04:47:00 INFO]: Constructing module Diamond Repair...
# [04:47:00 INFO]: Constructing module Dispensers Place Blocks...
# [04:47:00 INFO]: Constructing module Double Door Opening...
# [04:47:00 INFO]: Constructing module Dragon Scales...
# [04:47:00 INFO]: Constructing module Duskbound Blocks...
# [04:47:00 INFO]: Constructing module Dyeable Item Frames...
# [04:47:00 INFO]: Constructing module Easy Transfering...
# [04:47:00 INFO]: Constructing module Elytra Indicator...
# [04:47:00 INFO]: Constructing module Emotes...
# [04:47:00 INFO]: Constructing module Enchantment Predicates...
# [04:47:00 INFO]: Constructing module Enchantments Begone...
# [04:47:00 INFO]: Constructing module Ender Watcher...
# [04:47:00 INFO]: Constructing module Endermosh Music Disc...
# [04:47:00 INFO]: Constructing module Enhanced Ladders...
# [04:47:00 INFO]: Constructing module Expanded Item Interactions...
# [04:47:00 INFO]: Constructing module Fairy Rings...
# [04:47:00 INFO]: Constructing module Feeding Trough...
# [04:47:00 INFO]: Constructing module Forgotten...
# [04:47:00 INFO]: Constructing module Foxhound...
# [04:47:00 INFO]: Constructing module Framed Glass...
# [04:47:00 INFO]: Constructing module Game Nerfs...
# [04:47:00 INFO]: Constructing module Glass Item Frame...
# [04:47:00 INFO]: Constructing module Glass Shard...
# [04:47:00 INFO]: Constructing module Glimmering Weald...
# [04:47:00 INFO]: Constructing module Gold Bars...
# [04:47:00 INFO]: Constructing module Gold Tools Have Fortune...
# [04:47:00 INFO]: Constructing module Grab Chickens...
# [04:47:00 INFO]: Constructing module Grate...
# [04:47:00 INFO]: Constructing module Gravisand...
# [04:47:00 INFO]: Constructing module Greener Grass...
# [04:47:00 INFO]: Constructing module Hedges...
# [04:47:00 INFO]: Constructing module Hoe Harvesting...
# [04:47:00 INFO]: Constructing module Hollow Logs...
# [04:47:00 INFO]: Constructing module Horses Swim...
# [04:47:00 INFO]: Constructing module Hotbar Changer...
# [04:47:00 INFO]: Constructing module Improved Sponges...
# [04:47:00 INFO]: Constructing module Improved Tooltips...
# [04:47:00 INFO]: Constructing module Industrial Palette...
# [04:47:00 INFO]: Constructing module Inventory Sorting...
# [04:47:00 INFO]: Constructing module Iron Rod...
# [04:47:00 INFO]: Constructing module Item Sharing...
# [04:47:00 INFO]: Constructing module Japanese Palette...
# [04:47:00 INFO]: Constructing module Leaf Carpet...
# [04:47:00 INFO]: Constructing module Lock Rotation...
# [04:47:00 INFO]: Constructing module Long Range Pick Block...
# [04:47:00 INFO]: Constructing module Magnets...
# [04:47:00 INFO]: Constructing module Map Washing...
# [04:47:00 INFO]: Constructing module Matrix Enchanting...
# [04:47:00 INFO]: Constructing module Metal Buttons...
# [04:47:00 INFO]: Constructing module Microcrafting Helper...
# [04:47:00 INFO]: Constructing module Midori...
# [04:47:00 INFO]: Constructing module Monster Box...
# [04:47:00 INFO]: Constructing module More Banner Layers...
# [04:47:00 INFO]: Constructing module More Brick Types...
# [04:47:00 INFO]: Constructing module More Mud Blocks...
# [04:47:00 INFO]: Constructing module More Note Block Sounds...
# [04:47:00 INFO]: Constructing module More Potted Plants...
# [04:47:00 INFO]: Constructing module Narrator Readout...
# [04:47:00 INFO]: Constructing module Nether Brick Fence Gate...
# [04:47:00 INFO]: Constructing module Nether Obsidian Spikes...
# [04:47:00 INFO]: Constructing module New Stone Types...
# [04:47:00 INFO]: Constructing module No Durability On Cosmetics...
# [04:47:00 INFO]: Constructing module No More Lava Pockets...
# [04:47:00 INFO]: Constructing module Obsidian Plate...
# [04:47:00 INFO]: Constructing module Overlay Shader...
# [04:47:00 INFO]: Constructing module Parrot Eggs...
# [04:47:00 INFO]: Constructing module Pat The Dogs...
# [04:47:00 INFO]: Constructing module Pathfinder Maps...
# [04:47:00 INFO]: Constructing module Permafrost...
# [04:47:00 INFO]: Constructing module Pickarang...
# [04:47:00 INFO]: Constructing module Pig Litters...
# [04:47:00 INFO]: Constructing module Pipes...
# [04:47:00 INFO]: Constructing module Pistons Move Tile Entities...
# [04:47:00 INFO]: Constructing module Poison Potato Usage...
# [04:47:00 INFO]: Constructing module Quick Armor Swapping...
# [04:47:00 INFO]: Constructing module Rainbow Lamps...
# [04:47:00 INFO]: Constructing module Raw Metal Bricks...
# [04:47:00 INFO]: Constructing module Reacharound Placing...
# [04:47:00 INFO]: Constructing module Redstone Randomizer...
# [04:47:00 INFO]: Constructing module Renewable Spore Blossoms...
# [04:47:00 INFO]: Constructing module Replace Scaffolding...
# [04:47:00 INFO]: Constructing module Rope...
# [04:47:00 INFO]: Constructing module Safer Creatures...
# [04:47:00 INFO]: Constructing module Seed Pouch...
# [04:47:00 INFO]: Constructing module Shear Vines...
# [04:47:00 INFO]: Constructing module Shiba...
# [04:47:00 INFO]: Constructing module Shingles...
# [04:47:00 INFO]: Constructing module Shulker Packing...
# [04:47:00 INFO]: Constructing module Simple Harvest...
# [04:47:00 INFO]: Constructing module Skull Pikes...
# [04:47:00 INFO]: Constructing module Slabs To Blocks...
# [04:47:00 INFO]: Constructing module Slime In A Bucket...
# [04:47:00 INFO]: Constructing module Slimes To Magma Cubes...
# [04:47:00 INFO]: Constructing module Snow Golem Player Heads...
# [04:47:00 INFO]: Constructing module Soul Candles...
# [04:47:00 INFO]: Constructing module Soul Sandstone...
# [04:47:00 INFO]: Constructing module Spawner Replacer...
# [04:47:00 INFO]: Constructing module Spiral Spires...
# [04:47:00 INFO]: Constructing module Stonelings...
# [04:47:00 INFO]: Constructing module Stools...
# [04:47:00 INFO]: Constructing module Sturdy Stone...
# [04:47:00 INFO]: Constructing module Thatch...
# [04:47:00 INFO]: Constructing module Tiny Potato...
# [04:47:00 INFO]: Constructing module Torch Arrow...
# [04:47:00 INFO]: Constructing module Toretoise...
# [04:47:00 INFO]: Constructing module Totem Of Holding...
# [04:47:00 INFO]: Constructing module Trowel...
# [04:47:00 INFO]: Constructing module Usage Ticker...
# [04:47:00 INFO]: Constructing module Uses For Curses...
# [04:47:00 INFO]: Constructing module Utility Recipes...
# [04:47:00 INFO]: Constructing module Variant Animal Textures...
# [04:47:00 INFO]: Constructing module Variant Bookshelves...
# [04:47:00 INFO]: Constructing module Variant Chests...
# [04:47:00 INFO]: Registering C2S receiver with id architectury:sync_ids
# [04:47:00 INFO]: Constructing module Variant Furnaces...
# [04:47:00 INFO]: Constructing module Variant Ladders...
# [04:47:00 INFO]: Constructing module Variant Selector...
# [04:47:00 INFO]: Constructing module Vertical Planks...
# [04:47:00 INFO]: Constructing module Vertical Slabs...
# [04:47:00 INFO]: Constructing module Vexes Die With Their Masters...
# [04:47:00 INFO]: Constructing module Villager Rerolling Rework...
# [04:47:00 INFO]: Constructing module Villagers Follow Emeralds...
# [04:47:00 INFO]: Constructing module Wooden Posts...
# [04:47:00 INFO]: Constructing module Wool Shuts Up Minecarts...
# [04:47:00 INFO]: Constructing module Wraith...
# [04:47:00 INFO]: Constructing module Zombie Villagers On Normal...
# [04:47:00 INFO]: Constructing module More Stone Variants...
# [04:47:00 INFO]: Constructed 160 modules.
# [04:47:00 INFO]: Constructing common components for puzzleslib:main
# [04:47:01 INFO]: Initialized Chisels&Bits - Forge
# [04:47:01 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/quark-common.toml is not correct. Correcting
# [04:47:01 INFO]: Loaded block entity configuration.
# [04:47:01 INFO]: Loaded block configuration.
# [04:47:01 INFO]: Loaded chisel mode group configuration.
# /workspaces/codespaces-jupyter/Minecraft-server/config
# [04:47:01 INFO]: Loaded chisel mode configuration.
# [04:47:01 INFO]: Loaded container type configuration.
# [04:47:01 INFO]: Loaded item group configuration.
# [04:47:01 INFO]: Loaded item configuration.
# [04:47:01 INFO]: Loaded metadata key configuration.
# [04:47:01 INFO]: Loaded model property configuration.
# [04:47:01 INFO]: Loaded modification operation configuration.
# [04:47:01 INFO]: Loaded modification operation group configuration.
# [04:47:01 INFO]: Loaded pattern placement type configuration.
# [04:47:01 INFO]: Loaded recipe serializer configuration.
# [04:47:01 INFO]: Loaded tag configuration.
# [04:47:01 INFO]: Registering recipe types.
# [04:47:01 INFO]: Registering event handlers
# [04:47:02 INFO]: Dispatching ZRegister to 3 listeners
# [04:47:02 INFO]: Dispatching ZRegister$Post to 1 listener
# [04:47:02 INFO]: Dispatching ZRegister to 96 listeners
# [04:47:05 INFO]: Dispatching ZRegister$Post to 6 listeners
# [04:47:07 INFO]: Initialized block sets in 23ms
# [04:47:09 INFO]: Dispatching ForgeZEntityAttributeCreation (as ZEntityAttributeCreation) to 7 listeners
# [04:47:09 INFO]: Dispatching ZConfigChanged to 2 listeners
# [04:47:09 INFO]: 'zeta' is enabling Zeta's piston structure resolver.
# [04:47:09 INFO]: Dispatching ZConfigChanged to 2 listeners
# [04:47:09 INFO]: Dispatching ZConfigChanged to 2 listeners
# [04:47:09 INFO]: Dispatching ZConfigChanged to 45 listeners
# [04:47:09 INFO]: Dispatching ZConfigChanged to 45 listeners
# [04:47:09 INFO]: Registering Packets!
# [04:47:09 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 2 listeners
# [04:47:09 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 40 listeners
# [04:47:10 INFO]: Initialized color sets in 67ms
# [04:47:10 INFO]: Dispatching ZConfigChanged to 45 listeners
# [04:47:10 INFO]: Dispatching ZConfigChanged to 2 listeners
# [04:47:10 INFO]: Finished mod setup in: [18, 7, 0, 0, 0, 0, 12, 1] ms
# [04:47:10 INFO]: Got IMC []
# [04:47:10 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 1 listener
# [04:47:10 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 6 listeners
# [04:47:10 INFO]: Loaded values for 78 compatible attributes.
# [04:47:10 INFO]: Loaded 78 values from config.
# [04:47:10 INFO]: Saving config file. 78 entries.
# [04:47:10 INFO]: Applying changes for 78 attributes.
# [04:47:15 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [04:47:19 INFO]: Generated runtime SERVER_DATA for pack Supplementaries Generated Pack (supplementaries) in: 29 ms
# [04:47:20 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/server/commands/EnchantCommand
# [04:47:21 INFO]: Adding datapack listener capsid_recipes
# [04:47:21 INFO]: Adding datapack listener altar_of_amethyst_recipes
# [04:47:21 INFO]: Dispatching ForgeZAddReloadListener (as ZAddReloadListener) to 2 listeners
# [04:47:21 INFO]: Dispatching ForgeZAddReloadListener (as ZAddReloadListener) to 2 listeners
# [04:47:21 INFO]: Dispatching AdvancementModifierRegistry$1 (as ZGatherAdvancementModifiers) to 1 listener
# [04:47:24 INFO]: Registered 33 additional loot tables.
# [04:47:24 INFO]: Skipping loading recipe supplementaries:inspirations/blackboard_clear as it's serializer returned null
# [04:47:24 ERROR]: Parsing error loading recipe irons_spellbooks:dev_staff
# com.google.gson.JsonSyntaxException: Unknown item 'irons_spellbooks:dev_staff'
# 	at net.minecraftforge.common.crafting.CraftingHelper.getItem(CraftingHelper.java:160) ~[forge-1.20.1-47.2.20-universal.jar%23349!/:?]
# 	at net.minecraftforge.common.crafting.CraftingHelper.getItemStack(CraftingHelper.java:186) ~[forge-1.20.1-47.2.20-universal.jar%23349!/:?]
# 	at net.minecraft.world.item.crafting.ShapedRecipe.m_151274_(ShapedRecipe.java:355) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.world.item.crafting.ShapedRecipe$Serializer.m_6729_(ShapedRecipe.java:380) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.world.item.crafting.ShapedRecipe$Serializer.m_6729_(ShapedRecipe.java:370) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraftforge.common.extensions.IForgeRecipeSerializer.fromJson(IForgeRecipeSerializer.java:23) ~[forge-1.20.1-47.2.20-universal.jar%23349!/:?]
# 	at net.minecraft.world.item.crafting.RecipeManager.fromJson(RecipeManager.java:186) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.world.item.crafting.RecipeManager.m_5787_(RecipeManager.java:77) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.world.item.crafting.RecipeManager.m_5787_(RecipeManager.java:37) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.server.packs.resources.SimplePreparableReloadListener.m_10789_(SimplePreparableReloadListener.java:13) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at java.util.concurrent.CompletableFuture$UniAccept.tryFire(CompletableFuture.java:718) ~[?:?]
# 	at java.util.concurrent.CompletableFuture$Completion.run(CompletableFuture.java:482) ~[?:?]
# 	at net.minecraft.server.packs.resources.SimpleReloadInstance.m_143940_(SimpleReloadInstance.java:69) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.Util.m_214652_(Util.java:783) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.Util.m_214679_(Util.java:772) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.server.Main.main(Main.java:220) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:103) ~[?:?]
# 	at java.lang.reflect.Method.invoke(Method.java:580) ~[?:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.runTarget(CommonLaunchHandler.java:111) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.serverService(CommonLaunchHandler.java:103) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonServerLaunchHandler.lambda$makeService$0(CommonServerLaunchHandler.java:27) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandlerDecorator.launch(LaunchServiceHandlerDecorator.java:30) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:53) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:71) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.run(Launcher.java:108) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.main(Launcher.java:78) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:26) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:23) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.bootstraplauncher.BootstrapLauncher.main(BootstrapLauncher.java:141) [bootstraplauncher-1.1.2.jar:?]
# 	at com.mohistmc.MohistMCStart.main(MohistMCStart.java:106) [mohist.jar:1.20.1-580]
# [04:47:24 INFO]: Skipping loading recipe supplementaries:inspirations/flag_dye as it's serializer returned null
# [04:47:24 INFO]: Skipping loading recipe supplementaries:inspirations/flag_clear as it's serializer returned null
# [04:47:24 INFO]: Loaded 41 recipes
# [04:47:24 ERROR]: Parsing error loading custom advancement supplementaries:recipes/planter_rich: Unknown item id 'farmersdelight:rich_soil'
# [04:47:25 ERROR]: Parsing error loading custom advancement irons_spellbooks:irons_spellbooks/magic_aura_dupe: Expected item to be an item, was unknown string 'irons_spellbooks:enchanted_ward_amulet'
# [04:47:25 INFO]: [Automatic Recipe Unlock] Removed 2676 recipe advancements
# [04:47:25 INFO]: Loaded 916 advancements
# [04:47:25 INFO]: Registered 27 additional recipes.
# [04:47:25 INFO]: Clearing item tag to light level mapping cache
# [04:47:25 INFO]: Beginning loading of data for data loader: spawn_tables
# [04:47:25 INFO]: Data loader for spawn_tables loaded 8 jsons
# [04:47:25 INFO]: Beginning loading of data for data loader: entities
# [04:47:25 INFO]: Data loader for entities loaded 37 jsons
# [04:47:25 WARN]: Could not decode GlobalLootModifier with json id domesticationinnovation:blazing_enchanted_book - error: Not a JSON object: null
# [04:47:25 INFO]: Loaded 15 curio slots
# [04:47:25 INFO]: Loaded 1 curio entities
# [04:47:25 INFO]: Modified advancement minecraft:husbandry/wax_on with 2 patches
# [04:47:25 INFO]: Modified advancement minecraft:adventure/kill_a_mob with 3 patches
# [04:47:25 INFO]: Modified advancement minecraft:husbandry/bred_all_animals with 3 patches
# [04:47:25 INFO]: Modified advancement minecraft:adventure/kill_all_mobs with 3 patches
# [04:47:25 INFO]: Modified advancement minecraft:husbandry/balanced_diet with 3 patches
# [04:47:25 INFO]: Modified advancement minecraft:husbandry/plant_seed with 1 patches
# [04:47:25 INFO]: Modified advancement minecraft:nether/all_effects with 2 patches
# [04:47:25 INFO]: Modified advancement minecraft:husbandry/wax_off with 2 patches
# [04:47:25 INFO]: Modified advancement minecraft:adventure/adventuring_time with 1 patches
# [04:47:25 INFO]: Modified advancement minecraft:nether/all_potions with 1 patches
# [04:47:25 INFO]: Loaded 27 flute songs
# [04:47:25 INFO]: Registered 16 gear_sets.
# [04:47:25 INFO]: Registered 29 enchanting_stats.
# [04:47:25 INFO]: Registered 6 rarities.
# [04:47:25 INFO]: Registered 105 affixes.
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:rare for category curios:spellbookRequired: 2; Provided: 0
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:rare for category curios:necklaceRequired: 2; Provided: 1
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:rare for category curios:ringRequired: 2; Provided: 0
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:epic for category curios:spellbookRequired: 2; Provided: 0
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:epic for category curios:necklaceRequired: 2; Provided: 1
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:epic for category curios:ringRequired: 2; Provided: 0
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:mythic for category helmetRequired: 3; Provided: 2
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:mythic for category bootsRequired: 3; Provided: 2
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:mythic for category curios:spellbookRequired: 3; Provided: 0
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:mythic for category curios:necklaceRequired: 3; Provided: 1
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:mythic for category curios:ringRequired: 3; Provided: 0
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category helmetRequired: 4; Provided: 2
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category bootsRequired: 4; Provided: 2
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category curios:spellbookRequired: 4; Provided: 0
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category curios:necklaceRequired: 4; Provided: 1
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category curios:ringRequired: 4; Provided: 0
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category bowRequired: 5; Provided: 4
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category crossbowRequired: 5; Provided: 4
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category pickaxeRequired: 5; Provided: 4
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category shovelRequired: 5; Provided: 4
# [04:47:25 ERROR]: Insufficient number of affixes to satisfy the loot rules (ignoring backup rules) of rarity apotheosis:ancient for category curios:ringRequired: 5; Provided: 4
# [04:47:25 ERROR]: Codec failure for type gems, message: Unknown element name:spellbook
# [04:47:25 ERROR]: Failed parsing gems file irons_spellbooks:evocation.
# [04:47:25 ERROR]: Underlying Exception:
# java.lang.RuntimeException: Unknown element name:spellbook
# 	at com.mojang.serialization.DataResult.lambda$getOrThrow$5(DataResult.java:101) ~[datafixerupper-6.0.8.jar%23164!/:?]
# 	at com.mojang.datafixers.util.Either$Right.map(Either.java:99) ~[datafixerupper-6.0.8.jar%23164!/:?]
# 	at com.mojang.serialization.DataResult.getOrThrow(DataResult.java:93) ~[datafixerupper-6.0.8.jar%23164!/:?]
# 	at dev.shadowsoffire.placebo.reload.DynamicRegistry.lambda$apply$0(DynamicRegistry.java:140) ~[Placebo-1.20.1-8.6.1.jar%23318!/:8.6.1]
# 	at java.util.HashMap.forEach(HashMap.java:1429) ~[?:?]
# 	at dev.shadowsoffire.placebo.reload.DynamicRegistry.apply(DynamicRegistry.java:136) ~[Placebo-1.20.1-8.6.1.jar%23318!/:8.6.1]
# 	at dev.shadowsoffire.placebo.reload.DynamicRegistry.m_5787_(DynamicRegistry.java:62) ~[Placebo-1.20.1-8.6.1.jar%23318!/:8.6.1]
# 	at net.minecraft.server.packs.resources.SimplePreparableReloadListener.m_10789_(SimplePreparableReloadListener.java:13) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at java.util.concurrent.CompletableFuture$UniAccept.tryFire(CompletableFuture.java:718) ~[?:?]
# 	at java.util.concurrent.CompletableFuture$Completion.run(CompletableFuture.java:482) ~[?:?]
# 	at net.minecraft.server.packs.resources.SimpleReloadInstance.m_143940_(SimpleReloadInstance.java:69) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.Util.m_214652_(Util.java:783) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.Util.m_214679_(Util.java:772) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at net.minecraft.server.Main.main(Main.java:220) ~[server-1.20.1-20230612.114412-srg.jar%23344!/:?]
# 	at jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:103) ~[?:?]
# 	at java.lang.reflect.Method.invoke(Method.java:580) ~[?:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.runTarget(CommonLaunchHandler.java:111) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.serverService(CommonLaunchHandler.java:103) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonServerLaunchHandler.lambda$makeService$0(CommonServerLaunchHandler.java:27) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandlerDecorator.launch(LaunchServiceHandlerDecorator.java:30) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:53) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:71) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.run(Launcher.java:108) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.main(Launcher.java:78) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:26) [modlauncher-10.0.9.jar%23101!/:?]
# ...
# t=2024-03-05T08:12:14+0000 lvl=warn msg="failed to open private leg" id=06b1e05828a3 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:12:27+0000 lvl=warn msg="failed to open private leg" id=0d3cd5e1aa92 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:13:29+0000 lvl=warn msg="failed to open private leg" id=6c7b5802137d typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T08:16:47+0000 lvl=warn msg="failed to open private leg" id=a3213877a10d typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:18:41+0000 lvl=warn msg="failed to open private leg" id=86ee7902c0e2 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:21:42+0000 lvl=warn msg="failed to open private leg" id=a93c58488668 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:22:51+0000 lvl=warn msg="failed to open private leg" id=78e95302f20e typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:25:38+0000 lvl=warn msg="failed to open private leg" id=19f51cf08c6a typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:25:56+0000 lvl=warn msg="failed to open private leg" id=1ada67e70729 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T08:27:26+0000 lvl=warn msg="failed to open private leg" id=d0f22e92b6a2 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:27:30+0000 lvl=warn msg="failed to open private leg" id=512aa348720c typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:34:31+0000 lvl=warn msg="failed to open private leg" id=2c6b8658d4d2 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:36:15+0000 lvl=warn msg="failed to open private leg" id=8cb81bbd0f6a typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T08:39:05+0000 lvl=warn msg="failed to open private leg" id=278c3b6faad3 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:40:28+0000 lvl=warn msg="failed to open private leg" id=1418ad851ef3 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:46:30+0000 lvl=warn msg="failed to open private leg" id=19e5a2345207 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:46:32+0000 lvl=warn msg="failed to open private leg" id=7ca0260aa8cb typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T08:51:41+0000 lvl=warn msg="failed to open private leg" id=4010c942f856 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:52:22+0000 lvl=warn msg="failed to open private leg" id=d711e5c827f6 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T08:55:58+0000 lvl=warn msg="failed to open private leg" id=26b4a39a2213 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T08:56:44+0000 lvl=warn msg="failed to open private leg" id=0a0fa6688539 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:01:52+0000 lvl=warn msg="failed to open private leg" id=8779dfa15c45 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:06:04+0000 lvl=warn msg="failed to open private leg" id=83c264f4f060 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T09:10:53+0000 lvl=warn msg="failed to open private leg" id=cf02aa2bd27f typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:11:03+0000 lvl=warn msg="failed to open private leg" id=bb81e484f862 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:15:00+0000 lvl=warn msg="failed to open private leg" id=0644d40e8c31 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T09:19:07+0000 lvl=warn msg="failed to open private leg" id=a8564a52381e typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:22:59+0000 lvl=warn msg="failed to open private leg" id=a624fcb94987 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:22:59+0000 lvl=warn msg="failed to open private leg" id=18971c667ed2 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T09:27:08+0000 lvl=warn msg="failed to open private leg" id=4223ff5a75eb typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:27:08+0000 lvl=warn msg="failed to open private leg" id=502491d098bd typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:34:47+0000 lvl=warn msg="failed to open private leg" id=1d7f3a013d4d typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:34:48+0000 lvl=warn msg="failed to open private leg" id=3e7a1d8f5c41 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T09:41:15+0000 lvl=warn msg="failed to open private leg" id=9cd91004a395 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:41:17+0000 lvl=warn msg="failed to open private leg" id=337028e52d6e typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:45:49+0000 lvl=warn msg="failed to open private leg" id=43de155a893c typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T09:47:20+0000 lvl=warn msg="failed to open private leg" id=23fb615bf7e0 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:49:17+0000 lvl=warn msg="failed to open private leg" id=a21c7d7baa3f typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:52:08+0000 lvl=warn msg="failed to open private leg" id=e38e18512a28 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:52:55+0000 lvl=warn msg="failed to open private leg" id=c2ed1b7e369c typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T09:59:09+0000 lvl=warn msg="failed to open private leg" id=594ec4ce8a9c typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T09:59:14+0000 lvl=warn msg="failed to open private leg" id=eb1f0bd7119f typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T10:04:02+0000 lvl=warn msg="failed to open private leg" id=1b7874166bb6 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T10:04:10+0000 lvl=warn msg="failed to open private leg" id=2017b2685647 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# t=2024-03-05T10:10:31+0000 lvl=warn msg="failed to open private leg" id=b7ac2471a2ef typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T10:10:32+0000 lvl=warn msg="failed to open private leg" id=138531d9f169 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T10:15:25+0000 lvl=warn msg="failed to open private leg" id=8046257f2b92 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# t=2024-03-05T10:16:15+0000 lvl=warn msg="failed to open private leg" id=6d79e12a28c7 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
